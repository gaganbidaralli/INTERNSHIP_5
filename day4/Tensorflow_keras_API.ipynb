# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()
train_images = train_images.reshape((60000, 28*28))/ 255.0
test_images = test_images.reshape((10000, 28*28))/255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
plt.figure(figsize = (10, 5))
for i in range(20):
    plt.subplot(4, 5, i + 1)
    plt.imshow(train_images[i].reshape(28, 28), cmap = 'gray')
    plt.title(f"Label: {train_labels[i]}")
    plt.axis('off')

plt.suptitle('Sample MNIST Images with labels', y = 1.02)
plt.tight_layout()
plt.show()

# %%
from tensorflow.keras import regularizers

model = models.Sequential([
    layers.Dense(1024, activation='swish', kernel_regularizer=regularizers.l2(1e-4), input_shape=(784,)),
    layers.BatchNormalization(),
    layers.Dropout(0.4),

    layers.Dense(512, activation='swish', kernel_regularizer=regularizers.l2(1e-4)),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    layers.Dense(256, activation='swish', kernel_regularizer=regularizers.l2(1e-4)),
    layers.BatchNormalization(),
    layers.Dropout(0.1),

    layers.Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer = 'adam',
    loss = 'sparse_categorical_crossentropy',
    metrics = ['accuracy']
)

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

lr_schedule = ReduceLROnPlateau(
    monitor='val_accuracy', factor=0.5, patience=2, verbose=1
)

early_stop = EarlyStopping(
    monitor='val_accuracy', patience=5, restore_best_weights=True
)

history = model.fit(
    train_images, train_labels,
    epochs=100,
    batch_size=128,
    validation_data=(test_images, test_labels),
    callbacks=[lr_schedule, early_stop]
)
# Out:
# Epoch 1/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 27s 47ms/step - accuracy: 0.8845 - loss: 0.5487 - val_accuracy: 0.9672 - val_loss: 0.2648 - learning_rate: 0.0010
# Epoch 2/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 42s 49ms/step - accuracy: 0.9639 - loss: 0.2771 - val_accuracy: 0.9741 - val_loss: 0.2341 - learning_rate: 0.0010
# Epoch 3/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 23s 48ms/step - accuracy: 0.9701 - loss: 0.2455 - val_accuracy: 0.9742 - val_loss: 0.2283 - learning_rate: 0.0010
# Epoch 4/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 43s 52ms/step - accuracy: 0.9745 - loss: 0.2249 - val_accuracy: 0.9750 - val_loss: 0.2164 - learning_rate: 0.0010
# Epoch 5/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.9757 - loss: 0.2093 - val_accuracy: 0.9766 - val_loss: 0.2078 - learning_rate: 0.0010
# Epoch 6/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 39s 46ms/step - accuracy: 0.9788 - loss: 0.1970 - val_accuracy: 0.9775 - val_loss: 0.2007 - learning_rate: 0.0010
# Epoch 7/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 23s 49ms/step - accuracy: 0.9782 - loss: 0.1953 - val_accuracy: 0.9771 - val_loss: 0.1992 - learning_rate: 0.0010
# Epoch 8/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 43s 54ms/step - accuracy: 0.9793 - loss: 0.1880 - val_accuracy: 0.9794 - val_loss: 0.1880 - learning_rate: 0.0010
# Epoch 9/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.9819 - loss: 0.1792 - val_accuracy: 0.9807 - val_loss: 0.1836 - learning_rate: 0.0010
# Epoch 10/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 50ms/step - accuracy: 0.9804 - loss: 0.1816 - val_accuracy: 0.9782 - val_loss: 0.2044 - learning_rate: 0.0010
# Epoch 11/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9805 - loss: 0.1829
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 22s 47ms/step - accuracy: 0.9805 - loss: 0.1829 - val_accuracy: 0.9760 - val_loss: 0.2038 - learning_rate: 0.0010
# Epoch 12/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 43s 52ms/step - accuracy: 0.9860 - loss: 0.1609 - val_accuracy: 0.9841 - val_loss: 0.1618 - learning_rate: 5.0000e-04
# Epoch 13/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9900 - loss: 0.1370 - val_accuracy: 0.9837 - val_loss: 0.1521 - learning_rate: 5.0000e-04
# Epoch 14/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9901 - loss: 0.1249
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.9901 - loss: 0.1249 - val_accuracy: 0.9824 - val_loss: 0.1475 - learning_rate: 5.0000e-04
# Epoch 15/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 50ms/step - accuracy: 0.9897 - loss: 0.1196 - val_accuracy: 0.9857 - val_loss: 0.1318 - learning_rate: 2.5000e-04
# Epoch 16/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 23s 49ms/step - accuracy: 0.9932 - loss: 0.1048 - val_accuracy: 0.9869 - val_loss: 0.1220 - learning_rate: 2.5000e-04
# Epoch 17/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 23s 50ms/step - accuracy: 0.9936 - loss: 0.0976 - val_accuracy: 0.9855 - val_loss: 0.1238 - learning_rate: 2.5000e-04
# Epoch 18/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9939 - loss: 0.0911
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 42s 52ms/step - accuracy: 0.9939 - loss: 0.0911 - val_accuracy: 0.9842 - val_loss: 0.1209 - learning_rate: 2.5000e-04
# Epoch 19/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 39s 48ms/step - accuracy: 0.9956 - loss: 0.0843 - val_accuracy: 0.9866 - val_loss: 0.1144 - learning_rate: 1.2500e-04
# Epoch 20/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 23s 50ms/step - accuracy: 0.9958 - loss: 0.0798 - val_accuracy: 0.9871 - val_loss: 0.1101 - learning_rate: 1.2500e-04
# Epoch 21/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 50ms/step - accuracy: 0.9960 - loss: 0.0760 - val_accuracy: 0.9864 - val_loss: 0.1066 - learning_rate: 1.2500e-04
# Epoch 22/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9959 - loss: 0.0732
# Epoch 22: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 50ms/step - accuracy: 0.9959 - loss: 0.0732 - val_accuracy: 0.9862 - val_loss: 0.1078 - learning_rate: 1.2500e-04
# Epoch 23/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.9964 - loss: 0.0697 - val_accuracy: 0.9881 - val_loss: 0.1027 - learning_rate: 6.2500e-05
# Epoch 24/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 23s 49ms/step - accuracy: 0.9976 - loss: 0.0663 - val_accuracy: 0.9876 - val_loss: 0.1018 - learning_rate: 6.2500e-05
# Epoch 25/100
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9975 - loss: 0.0642
# Epoch 25: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 25s 53ms/step - accuracy: 0.9975 - loss: 0.0642 - val_accuracy: 0.9878 - val_loss: 0.1003 - learning_rate: 6.2500e-05
# Epoch 26/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.9979 - loss: 0.0623 - val_accuracy: 0.9875 - val_loss: 0.0986 - learning_rate: 3.1250e-05
# Epoch 27/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9974 - loss: 0.0621
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 23s 50ms/step - accuracy: 0.9974 - loss: 0.0621 - val_accuracy: 0.9871 - val_loss: 0.0992 - learning_rate: 3.1250e-05
# Epoch 28/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.9979 - loss: 0.0602 - val_accuracy: 0.9875 - val_loss: 0.0982 - learning_rate: 1.5625e-05

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"\nTest accuracy: {test_acc:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9851 - loss: 0.1153
#
# Test accuracy: 0.9881

# %%
# Plot training history
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Make predictions and visualize
predictions = model.predict(test_images)
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.imshow(test_images[i].reshape(28, 28), cmap='gray')
    pred_label = np.argmax(predictions[i])
    true_label = test_labels[i]
    color = 'green' if pred_label == true_label else 'red'
    plt.title(f"Pred: {pred_label}\nTrue: {true_label}", color=color)
    plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
